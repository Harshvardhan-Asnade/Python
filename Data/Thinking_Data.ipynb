# %%
import json

# %%
def load_data(filename): 
    with open(filename,'r') as f: 
        data=json.load(f)

    return data

# %%
data =load_data("Example_store_data ")
print(data)
print(type(data))
# Out:
# <class 'list'>
